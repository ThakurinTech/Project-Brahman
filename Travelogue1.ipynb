# %%
#Book 1 Autobiography of a Yogi

#THIS IS WITHOUT ANY PRE-PROCESSING STEPS for Book 1

from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Load pre-trained tokenizer and model for NER
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-ner-english")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-large-ner-english")

# Define your data
mydata = "/Users/shikha/Desktop/GJ/AOY/AOY.txt"

# Initialize NER pipeline with modified aggregation_strategy
nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="average")

# Chunk size for iterating over the text
chunk_size = 1000

# Read text from file and process in chunks
with open(mydata, "r", encoding="utf-8") as file:
    text = file.read()
    # Process text in chunks
    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        # Perform NER on the chunk
        output = nlp(chunk)
        # Filter the output to keep only the entities labeled as LOC
        locations = [entity for entity in output if entity['entity_group'] == 'LOC']
        # Print the extracted locations
        for location in locations:
            print(location)
# Out:
# {'entity_group': 'LOC', 'score': 0.99982506, 'word': ' India', 'start': 189, 'end': 194}
# {'entity_group': 'LOC', 'score': 0.99994516, 'word': ' India', 'start': 551, 'end': 556}
# {'entity_group': 'LOC', 'score': 0.6647028, 'word': ' Puri,', 'start': 49, 'end': 54}
# {'entity_group': 'LOC', 'score': 0.665906, 'word': ' Orissa,', 'start': 58, 'end': 65}
# {'entity_group': 'LOC', 'score': 0.9914689, 'word': ' Bay of', 'start': 73, 'end': 79}
# {'entity_group': 'LOC', 'score': 0.99987423, 'word': ' States', 'start': 342, 'end': 348}
# {'entity_group': 'LOC', 'score': 0.6648167, 'word': ' Puri,', 'start': 250, 'end': 255}
# {'entity_group': 'LOC', 'score': 0.9077375, 'word': ' Temple of', 'start': 373, 'end': 382}
# {'entity_group': 'LOC', 'score': 0.73719037, 'word': ' of the', 'start': 400, 'end': 406}
# {'entity_group': 'LOC', 'score': 0.9971818, 'word': ' Puri', 'start': 425, 'end': 429}
# ...

# %%
#THIS IS WITH PRE-PROCESSING STEPS for book 1

from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Load pre-trained tokenizer and model for NER
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-ner-english")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-large-ner-english")

# Define your data
mydata = "/Users/shikha/Desktop/GJ/AOY/AOY.txt"

# Initialize NER pipeline with modified aggregation_strategy
nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="average")

# Chunk size for iterating over the text
chunk_size = 1000

# Read text from file and process in chunks
with open(mydata, "r", encoding="utf-8") as file:
    text = file.read()
    # Preprocess the text
    text = text.replace('\n', ' ').replace('.', ' ').replace(',', ' ')
    # Process text in chunks
    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        # Perform NER on the chunk
        output = nlp(chunk)
        # Filter the output to keep only the entities labeled as LOC
        locations = [entity for entity in output if entity['entity_group'] == 'LOC']
        # Print the extracted locations
        for location in locations:
            print(location)
# Out:
# {'entity_group': 'LOC', 'score': 0.9999236, 'word': ' India', 'start': 189, 'end': 194}
# {'entity_group': 'LOC', 'score': 0.99995494, 'word': ' India', 'start': 551, 'end': 556}
# {'entity_group': 'LOC', 'score': 0.9999448, 'word': ' America', 'start': 561, 'end': 568}
# {'entity_group': 'LOC', 'score': 0.9998877, 'word': ' India', 'start': 765, 'end': 770}
# {'entity_group': 'LOC', 'score': 0.89725, 'word': ' West', 'start': 800, 'end': 804}
# {'entity_group': 'LOC', 'score': 0.9945291, 'word': ' Puri', 'start': 49, 'end': 53}
# {'entity_group': 'LOC', 'score': 0.9986701, 'word': ' Orissa', 'start': 58, 'end': 64}
# {'entity_group': 'LOC', 'score': 0.9966356, 'word': ' Bay of Bengal', 'start': 73, 'end': 86}
# {'entity_group': 'LOC', 'score': 0.99982035, 'word': ' United States', 'start': 335, 'end': 348}
# {'entity_group': 'LOC', 'score': 0.9980275, 'word': ' Americas', 'start': 364, 'end': 372}
# ...

# %%
#ADDING FILTERS/RULES TO TAILOR SPECIFIC ELEMENTS FOR REMOVING DUPLICATES

import csv
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Load pre-trained tokenizer and model for NER
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-ner-english")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-large-ner-english")

# Define your data
mydata = "/Users/shikha/Desktop/GJ/AOY/AOY.txt"

# Initialize NER pipeline with modified aggregation_strategy
nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="average")

# Chunk size for iterating over the text
chunk_size = 1000

# Initialize an empty list to store unique locations
unique_locations = []

# Read text from file and process in chunks
with open(mydata, "r", encoding="utf-8") as file:
    text = file.read()

    # Preprocess the text
    text = text.replace('\n', ' ').replace('.', ' ').replace(',', ' ')

    # Process text in chunks
    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        # Perform NER on the chunk
        output = nlp(chunk)
        # Write the locations to the CSV file
        for entity in output:
            if entity['entity_group'] == 'LOC':  # Check if the entity is a location
                location = entity['word'].strip()  # Remove leading/trailing whitespace
                if location.isalpha() and location not in unique_locations:  # Filter by alphabetic characters and uniqueness
                    unique_locations.append(location)  # Add location to the list

# Convert the list of unique locations to a DataFrame
df = pd.DataFrame({'A': unique_locations})

# Get unique values of 'A' column (locations)
unique_values = df['A'].unique()

print(unique_values)
# Out:
# ['India' 'America' 'West' 'Puri' 'Orissa' 'Americas' 'England'
#  'California' 'of' 'World' 'Babylon' 'Egypt' 'Gorakhpur' 'Benares'
#  'Ichapur' 'Bengal' 'Himalayas' 'Lahore' 'Punjab' 'Madras' 'Calcutta'
#  'Bareilly' 'heaven' 'SHEOLI' 'Ganges' 'GHAT' 'HIMALAYAS' 'Burdwan'
#  'Hardwar' 'M' 'Rishikesh' 'Serampore' 'Howrah' 'Khulna' 'Thebes' 'Tibet'
#  'Asia' 'Europe' 'East' 'Fontainebleau' 'Bhowanipur' 'MATH' 'ASHRAM'
#  'Cambridge' 'Nalanda' 'Taxila' 'Botany' 'Pennsylvania' 'St' 'Washington'
#  'D' 'C' 'Konnersreuth' 'Bavaria' 'Dakshineswar' 'GOLDIGHI' 'Nantu' 'Kasi'
#  'BRINDABAN' 'Agra' 'Brindaban' 'amoyima' 'Ranikhet' 'Taj' 'Muttra'
#  'Jerusalem' 'Eden' 'idyl' 'MAYA' 'Hollywood' 'hollywood' 'Ranchi'
#  'Pacific' 'Shankara' 'sylvan' 'Kashmir' 'Edinburgh' 'Ranbajpur'
#  'Tarakeswar' 'Lourdes' 'France' 'vales' 'Mirth' 'PURI' 'London'
#  'Pasadena' 'PANTHI' 'mountai' 'CALCUTTA' 'SERAMPORE' 'KASHMIR' 'Himavat'
#  'Simla' 'Hima' 'Massachusetts' 'Rawalpindi' 'Srinagar' 'Gulmarg'
# ...

# %%
#ADDING FILTERS/RULES TO TAILOR SPECIFIC ELEMENTS FOR REMOVING DUPLICATES

import csv
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Load pre-trained tokenizer and model for NER
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-ner-english")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-large-ner-english")

# Define your data
mydata = "/Users/shikha/Desktop/GJ/AOY/AOY.txt"

# Initialize NER pipeline with modified aggregation_strategy
nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="average")

# Chunk size for iterating over the text
chunk_size = 1000

# Initialize an empty set to store unique locations
unique_locations = set()

# Read text from file and process in chunks
with open(mydata, "r", encoding="utf-8") as file:
    text = file.read()

    # Preprocess the text
    text = text.replace('\n', ' ').replace('.', ' ').replace(',', ' ')

    # Process text in chunks
    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        # Perform NER on the chunk
        output = nlp(chunk)
        # Write the locations to the CSV file
        for entity in output:
            if entity['entity_group'] == 'LOC':  # Check if the entity is a location
                location = entity['word'].strip().title()  # Remove leading/trailing whitespace and capitalize the word
                if location.isalpha():  # Filter by alphabetic characters
                    unique_locations.add(location)  # Add location to the set

# Convert the set of unique locations to a DataFrame
df = pd.DataFrame({'A': sorted(unique_locations)})

# Get unique values of 'A' column (locations)
unique_values = df['A'].unique()

print(unique_values)
# Out:
# ['Afghanistan' 'Africa' 'Agra' 'Ahasaya' 'Ajanta' 'Al' 'Alaska' 'Alilee'
#  'Allahabad' 'Almora' 'Alps' 'Amarnath' 'America' 'Americas' 'Amoyima'
#  'Arabian' 'Aranya' 'Archangel' 'Aryavarta' 'Ashram' 'Asia' 'Aska'
#  'Assisi' 'Athens' 'Atlantis' 'Babylon' 'Badrinarayan' 'Badrinath'
#  'Baluchistan' 'Bangalore' 'Bankura' 'Barackpur' 'Bareilly' 'Bavaria'
#  'Belgium' 'Belur' 'Benares' 'Bengal' 'Bengalitola' 'Bethlehem'
#  'Bhadravati' 'Bharati' 'Bhowanipur' 'Bihar' 'Bishnupur' 'Biur' 'Bolpur'
#  'Bombay' 'Boston' 'Botany' 'Bowbazar' 'Brindaban' 'Burbank' 'Burdwan'
#  'Burma' 'C' 'Cairo' 'Calcutta' 'California' 'Calvary' 'Cambridge'
#  'Chicago' 'China' 'Chitor' 'Cincinnati' 'Cleveland' 'Coast' 'Colorado'
#  'Conjeeveram' 'D' 'Dacca' 'Dakshineswar' 'Danapur' 'Delhi' 'Denver'
#  'Deogarh' 'Dihika' 'Dreams' 'East' 'Eden' 'Edinburgh' 'Egypt' 'Eichstatt'
#  'Ejmalichak' 'Ellora' 'Elysium' 'Encinitas' 'England' 'Europe'
# ...

# %%
import csv
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Load pre-trained tokenizer and model for NER
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-ner-english")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-large-ner-english")

# Define your data
mydata = "/Users/shikha/Desktop/GJ/AOY/AOY.txt"
output_csv = "/Users/shikha/Desktop/GJ/AOY/LOCATIONS.csv"

# Initialize NER pipeline with modified aggregation_strategy
nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="average")

# Chunk size for iterating over the text
chunk_size = 1000

# Open the CSV file in write mode and create a CSV writer
with open(output_csv, "w", newline='', encoding="utf-8") as csvfile:
    fieldnames = ['text', 'start', 'end']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    # Read text from file and preprocess
    with open(mydata, "r", encoding="utf-8") as file:
        text = file.read()
        # Preprocess the text
        text = text.replace('\n', ' ').replace('.', ' ').replace(',', ' ')
        # Process text in chunks
        for i in range(0, len(text), chunk_size):
            chunk = text[i:i+chunk_size]
            # Perform NER on the chunk
            output = nlp(chunk)
            # Filter the output to keep only the entities labeled as LOC
            locations = [entity for entity in output if entity['entity_group'] == 'LOC']
            # Write the extracted locations to the CSV file
            for location in locations:
                writer.writerow({'text': location['word'], 'start': location['start'], 'end': location['end']})

print("Extraction complete. Locations saved in:", output_csv)

# Read the CSV file into a DataFrame
df = pd.read_csv(output_csv)

# Get unique values of 'text' column
unique_locations = df['text'].unique()

# Print unique locations
print("Unique locations:", unique_locations)
# Out:
# Extraction complete. Locations saved in: /Users/shikha/Desktop/GJ/AOY/LOCATIONS.csv
# Unique locations: [' India' ' America' ' West' ' Puri' ' Orissa' ' Bay of Bengal'
#  ' United States' ' Americas' ' England' ' California'
#  ' Temple of Jagannath' ' of' ' World' ' Babylon' ' Egypt' ' Gorakhpur'
#  ' United Provinces' ' Benares' ' Ichapur' ' Bengal' ' Himalayas'
#  ' Lahore' ' Punjab' ' York:' ' Semudoss St' ' Madras' ' Calcutta'
#  ' Bareilly' ' Amherst Street' ' heaven' ' Naini Tal' ' SHEOLI' ' Ganges'
#  ' GHAT' ' HIMALAYAS' ' Gurpar Road' ' Chadni Chowk' ' Burdwan' ' Hardwar'
#  ' M' ' Moghul Ser' ' Rishikesh' ' Serampore' ' Howrah' ' Khulna'
#  ' Thebes' ' Kalighat Temple' ' Tibet' ' Asia' ' Europe' ' East'
#  ' Fontainebleau' ' Bhowanipur' ' Cooch Behar' ' Upper Circular'
#  ' Ram Mohan Roy Road' '�Nagendra Math' ' MATH' ' ASHRAM' ' Cambridge'
#  ' Nalanda' ' Taxila' ' Botany' ' Pennsylvania' ' St' ' Washington' ' D'
# ...

# %%
import csv
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Load pre-trained tokenizer and model for NER
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-ner-english")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-large-ner-english")

# Define your data
input_text_file = "/Users/shikha/Desktop/GJ/AOY/AOY.txt"
output_csv_file = "/Users/shikha/Desktop/GJ/AOY/LOCATIONS.csv"

# Initialize NER pipeline with modified aggregation_strategy
nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="average")

# Chunk size for iterating over the text
chunk_size = 1000

# Initialize an empty list to store locations
locations = []

# Write the locations to a CSV file
with open(output_csv_file, "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ['word', 'start', 'end']  # Define the field names for the CSV file
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    # Read text from file and process in chunks
    with open(input_text_file, "r", encoding="utf-8") as file:
        text = file.read()

        # Preprocess the text
        text = text.replace('\n', ' ').replace('.', ' ').replace(',', ' ')

        # Process text in chunks
        for i in range(0, len(text), chunk_size):
            chunk = text[i:i+chunk_size]
            # Perform NER on the chunk
            output = nlp(chunk)
            # Write the locations to the CSV file and collect them in a list
            for entity in output:
                if entity['entity_group'] == 'LOC':  # Check if the entity is a location
                    writer.writerow({'word': entity['word'], 'start': entity['start'], 'end': entity['end']})
                    locations.append(entity['word'])

# Read the CSV file into a DataFrame
df = pd.read_csv(output_csv_file)

# Remove duplicate locations while preserving the order
unique_locations = []
for location in locations:
    if location not in unique_locations:
        unique_locations.append(location)

# Save the unique locations back to the CSV file (optional)
df_unique = pd.DataFrame({'word': unique_locations})
df_unique.to_csv(output_csv_file, index=False)

# Use unique_locations for mapping or further processing
print("Unique locations:", unique_locations)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/pipelines/token_classification.py:392: UserWarning: Tokenizer does not support real words, using fallback heuristic
#   warnings.warn(
# ...

# %%
import csv
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# Load pre-trained tokenizer and model for NER
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-large-ner-english")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-large-ner-english")

# Define your data
mydata = "/Users/shikha/Desktop/GJ/AOY/AOY.txt"

# Initialize NER pipeline with modified aggregation_strategy
nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="average")

# Chunk size for iterating over the text
chunk_size = 1000

# Initialize an empty list to store unique locations
unique_locations = []

# Write the locations to a CSV file
with open("locations.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ['word', 'start', 'end']  # Define the field names for the CSV file
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    # Read text from file and process in chunks
    with open(mydata, "r", encoding="utf-8") as file:
        text = file.read()

        # Preprocess the text
        text = text.replace('\n', ' ').replace('.', ' ').replace(',', ' ')

        # Process text in chunks
        for i in range(0, len(text), chunk_size):
            chunk = text[i:i+chunk_size]
            # Perform NER on the chunk
            output = nlp(chunk)
            # Write the locations to the CSV file
            for entity in output:
                if entity['entity_group'] == 'LOC':  # Check if the entity is a location
                    location = entity['word'].strip()
                    if location.isalpha() and location.istitle() and len(location) > 2:  # Filter by capitalization, length, and alphabetic characters
                        writer.writerow({'word': location, 'start': entity['start'], 'end': entity['end']})
                        unique_locations.append(location)  # Add location to the list

# Convert the list of unique locations to a DataFrame
df = pd.DataFrame({'A': unique_locations})

# Get unique values of 'A' column (locations)
unique_values = df['A'].unique()

print(unique_values)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/pipelines/token_classification.py:392: UserWarning: Tokenizer does not support real words, using fallback heuristic
#   warnings.warn(
# ['India' 'America' 'West' 'Puri' 'Orissa' 'Americas' 'England'
#  'California' 'World' 'Babylon' 'Egypt' 'Gorakhpur' 'Benares' 'Ichapur'
#  'Bengal' 'Himalayas' 'Lahore' 'Punjab' 'Madras' 'Calcutta' 'Bareilly'
#  'Ganges' 'Burdwan' 'Hardwar' 'Rishikesh' 'Serampore' 'Howrah' 'Khulna'
#  'Thebes' 'Tibet' 'Asia' 'Europe' 'East' 'Fontainebleau' 'Bhowanipur'
#  'Cambridge' 'Nalanda' 'Taxila' 'Botany' 'Pennsylvania' 'Washington'
#  'Konnersreuth' 'Bavaria' 'Dakshineswar' 'Nantu' 'Kasi' 'Agra' 'Brindaban'
#  'Ranikhet' 'Taj' 'Muttra' 'Jerusalem' 'Eden' 'Hollywood' 'Ranchi'
#  'Pacific' 'Shankara' 'Kashmir' 'Edinburgh' 'Ranbajpur' 'Tarakeswar'
#  'Lourdes' 'France' 'Mirth' 'London' 'Pasadena' 'Himavat' 'Simla' 'Hima'
# ...

# %%
# Original list of locations

locations = [' India', ' America', ' West', ' Puri', ' Orissa', ' Bay of Bengal', ' United States', ' Americas', ' England', ' California', ' Temple of Jagannath', ' of', ' World', ' Babylon', ' Egypt', ' Gorakhpur', ' United Provinces', ' Benares', ' Ichapur', ' Bengal', ' Himalayas', ' Lahore', ' Punjab', ' York:', ' Semudoss St', ' Madras', ' Calcutta', ' Bareilly', ' Amherst Street', ' heaven', ' Naini Tal', ' SHEOLI', ' Ganges', ' GHAT', ' HIMALAYAS', ' Gurpar Road', ' Chadni Chowk', ' Burdwan', ' Hardwar', ' M', ' Moghul Ser', ' Rishikesh', ' Serampore', ' Howrah', ' Khulna', ' Thebes', ' Kalighat Temple', ' Tibet', ' Asia', ' Europe', ' East', ' Fontainebleau', ' Bhowanipur', ' Cooch Behar', ' Upper Circular', ' Ram Mohan Roy Road', '�Nagendra Math', ' MATH', ' ASHRAM', ' Cambridge', ' Nalanda', ' Taxila', ' Botany', ' Pennsylvania', ' St', ' Washington', ' D', ' C', ' Konnersreuth', ' Bavaria', ' Dakshineswar Temple', ' Temple of Kali', ' Dakshineswar', ' Merciful Presence', ' GOLDIGHI', ' Calcutta bathing GHATS', ' Nantu', ' Rana Mahal', ' Rai Ghat Lane', ' Kasi', ' Lahiri Mahasaya', ' Calcutta!', ' BRINDABAN', ' Agra', ' Taj Mahal', ' Brindaban', ' Brindaban?', ' Brindaban;', ' amoyima', ' Drongiri Mountains', ' Ranikhet', ' Madanamohana Temple', ' Taj', ' Muttra', ' Jerusalem', ' Calcutta;', ' Eden', ' idyl', ' MAYA', ' Mount Washington Estates', ' Los Angeles', ' Hollywood', ' hollywood', ' Ranchi', ' Pacific', ' Shankara', ' sylvan', ' Kashmir', ' Edinburgh', ' Ranbajpur', ' Tarakeswar', ' Lourdes', '
' Germany', ' K', ' onnersreuth', ' Bavaria—see', ' Holland', ' Swiss Alps', ' Italy', ' Assisi', ' Greece', ' Mediterranean', ' Palestine', ' Holy Land', ' Bethlehem', ' Gethsemane', ' Calvary', ' Mount of Olives', ' River Jordan', ' Sea of G', ' alilee', ' Birth Manger', ' Cairo', ' Red Sea', ' Arabian', ' Athens', ' Bombay', ' Taj Mahal Hotel', ' Howrah Station', ' Ranchi VIDYALAYA', ' Ejmalichak', ' Central Provinces', ' Wardha', ' Chamundi Temple', ' Mysore', ' Town Hall', ' Bangalore', ' Chetty Town Hall', ' Mysore:', ' Krishnaraja Sagar Dam', ' Hyderabad', ' Godavari River', ' Nilgiris', ' Mountains', ' Ellora', ' Ajanta', ' Kailasa', ' Hyderabad City', ' Mecca Masjid Mosque', ' enic wonderland', ' Belur', ' Afghanistan', ' Baluchistan', ' Seleucus', ' Patna', ' Hades', ' Persia', ' Susa', ' South India', ' Sravanabelagola', ' Travancore', ' Madras Presidency', ' Conjeeveram', ' Golden City', ' Nerur', ' Pudukkottai', ' Kaveri River', ' Madura', ' Mysore City', ' Kolar', ' Bhadravati', ' (Calcutta', ' (Lahore:', ' (SUDRA', ' (VAISYA', ' (KSHATRIYA', ' (BRAHMIN', ' Sringeri Math', ' Albert Hall', ' Santosh', ' Calcutta?', ' serampore', ' MELA', ' KUMBHA;', ' Jumna', ' Taj Mahal;', ' Katayani Peith Ashram', ' Lahir', ' Brindaban—see', ' Keshabananda', ' Jumna River', ' Chitor', ' Nasik', ' Ujjain', ' Regent Hotel', ' KUMBHA MELA?', ' HIRANYALOKA', '�Illumined Astral Planet', ' Hiranyaloka', ' SABIKALPA SAMADHI', ' NIRBIKALPA SAMADHI', ' Hiranyaloka-is', ' Sea of Bliss', ' Ocean', ' WARDHA', ' MAGANVADI', ' gandhi', ' Wardha?', ' Wardha idyl;', ' DANSE MACABRE', ' New', ' Pondicherry', ' (Ahmedabad:', ' Poona', ' Jamshedpur', ' Elysium', ' Ranchi;', ' Dehra Dun', ' Dacca', ' Nawabganj', ' Purulia;', ' Purulia', ' Biur', ' Giri Bala', ' Bankura', ' doorway-Giri Bala!', ' Nawabganj GHAT', ' Memphis', ' Grosvenor House', ' Whitefield’s Congregational Church', ' Windsor House', ' Southampton', ' corners-Palestine', ' Belgium', ' Nebraska', ' Chicago', ' Los', ' ENCINITAS', ' Encinitas', ' encinitas', ' Land', ' Dreams', ' the Temple of Silence', ' Carnegie Hall', '�Friendship Heights', ' Olive Hill', ' Los Angeles Planetarium', ' San Diego Bay', ' Philippines', ' Africa', '�Encinitas', ' San Francisco', ' Coast', ' 101']

# Cleaned list of locations
cleaned_locations = []

# Iterate through each location and clean it
for location in locations:
    # Remove leading and trailing spaces
    cleaned_location = location.strip()
    # Remove additional characters
    cleaned_location = cleaned_location.replace(':', '').replace(';', '').replace('?', '')
    # Capitalize each word
    cleaned_location = cleaned_location.title()
    # Append cleaned location to the list
    cleaned_locations.append(cleaned_location)

# Remove duplicates while preserving the order
cleaned_locations = list(dict.fromkeys(cleaned_locations))

(Calcutta', ' (Lahore:', ' (SUDRA', ' (VAISYA', ' (KSHATRIYA', ' (BRAHMIN', ' Sringeri Math', ' Albert Hall', ' Santosh', ' Calcutta?', ' serampore', ' MELA', ' KUMBHA;', ' Jumna', ' Taj Mahal;', ' Katayani Peith Ashram', ' Lahir', ' Brindaban—see', ' Keshabananda', ' Jumna River', ' Chitor', ' Nasik', ' Ujjain', ' Regent Hotel', ' KUMBHA MELA?', ' HIRANYALOKA', '�Illumined Astral Planet', ' Hiranyaloka', ' SABIKALPA SAMADHI', ' NIRBIKALPA SAMADHI', ' Hiranyaloka-is', ' Sea of Bliss', ' Ocean', ' WARDHA', ' MAGANVADI', ' gandhi', ' Wardha?', ' Wardha idyl;', ' DANSE MACABRE', ' New', ' Pondicherry', ' (Ahmedabad:', ' Poona', ' Jamshedpur', ' Elysium', ' Ranchi;', ' Dehra Dun', ' Dacca', ' Nawabganj', ' Purulia;', ' Purulia', ' Biur', ' Giri Bala', ' Bankura', ' doorway-Giri Bala!', ' Nawabganj GHAT', ' Memphis', ' Grosvenor House', ' Whitefield’s Congregational Church', ' Windsor House', ' Southampton', ' corners-Palestine', ' Belgium', ' Nebraska', ' Chicago', ' Los', ' ENCINITAS', ' Encinitas', ' encinitas', ' Land', ' Dreams', ' the Temple of Silence', ' Carnegie Hall', '�Friendship Heights', ' Olive Hill', ' Los Angeles Planetarium', ' San Diego Bay', ' Philippines', ' Africa', '�Encinitas', ' San Francisco', ' Coast', ' 101'] 

import re

def clean_locations(locations):
    cleaned_locations = []
    for location in locations:
        # Remove leading and trailing whitespaces
        location = location.strip()
        
        # Replace special characters with appropriate characters
        location = re.sub(r'[^\x00-\x7F]+', '', location)
        
        # Capitalize the first letter of each word
        location = ' '.join(word.capitalize() for word in location.split())
        
        # Replace known abbreviations with full words
        replacements = {
            "Of": "of",
            "St": "Street",
            "Math": "Mathematics",
            "C": "City",
            "Rai Ghat": "Rai Ghat",
            "Mela": "Fair",
            "Ghat": "Riverbank",
            "Is": "Island",
            "Wardha Idyl": "Wardha",
            "Danse Macabre": "Danse",
            "Brindaban—See": "Brindaban",
            "Ahmedabad": "Ahmedabad",
            "Sudra": "Sudra",
            "Vaisya": "Vaisya",
            "Kshatriya": "Kshatriya",
            "Brahmin": "Brahmin"
        }
        location = replacements.get(location, location)
        
        # Add to cleaned list
        cleaned_locations.append(location)
    
    # Remove duplicates
    cleaned_locations = list(set(cleaned_locations))
    return cleaned_locations

# %%
locations = ['India', ' America', ' West', ' Puri', ' Orissa', ' Bay of Bengal', ' United States', ' Americas', ' England', ' California', ' Temple of Jagannath', ' of', ' World', ' Babylon', ' Egypt', ' Gorakhpur', ' United Provinces', ' Benares', ' Ichapur', ' Bengal', ' Himalayas', ' Lahore', ' Punjab', ' York:', ' Semudoss St', ' Madras', ' Calcutta', ' Bareilly', ' Amherst Street', ' heaven', ' Naini Tal', ' SHEOLI', ' Ganges', ' GHAT', ' HIMALAYAS', ' Gurpar Road', ' Chadni Chowk', ' Burdwan', ' Hardwar', ' M', ' Moghul Ser', '
DANSE MACABRE', ' New', ' Pondicherry', ' (Ahmedabad:', ' Poona', ' Jamshedpur', ' Elysium', ' Ranchi;', ' Dehra Dun', ' Dacca', ' Nawabganj', ' Purulia;', ' Purulia', ' Biur', ' Giri Bala', ' Bankura', ' doorway-Giri Bala!', ' Nawabganj GHAT', ' Memphis', ' Grosvenor House', ' Whitefield’s Congregational Church', ' Windsor House', ' Southampton', ' corners-Palestine', ' Belgium', ' Nebraska', ' Chicago', ' Los', ' ENCINITAS', ' Encinitas', ' encinitas', ' Land', ' Dreams', ' the Temple of Silence', ' Carnegie Hall', '�Friendship Heights', ' Olive Hill', ' Los Angeles Planetarium', ' San Diego Bay', ' Philippines', ' Africa', '�Encinitas', ' San Francisco', ' Coast', ' 101']

import re

def clean_locations(locations):
    cleaned_locations = []
    for location in locations:
        # Remove leading and trailing whitespaces
        location = location.strip()
        
        # Replace special characters with appropriate characters
        location = re.sub(r'[^\x00-\x7F]+', '', location)
        
        # Capitalize the first letter of each word
        location = ' '.join(word.capitalize() for word in location.split())
        
        # Replace known abbreviations with full words
        replacements = {
            "Of": "of",
            "St": "Street",
            "Math": "Mathematics",
            "C": "City",
            "Rai Ghat": "Rai Ghat",
            "Mela": "Fair",
            "Ghat": "Riverbank",
            "Is": "Island",
            "Wardha Idyl": "Wardha",
            "Danse Macabre": "Danse",
            "Brindaban—See": "Brindaban",
            "Ahmedabad": "Ahmedabad",
            "Sudra": "Sudra",
            "Vaisya": "Vaisya",
            "Kshatriya": "Kshatriya",
            "Brahmin": "Brahmin"
        }
        location = replacements.get(location, location)
        
        # Remove duplicates
        if location not in cleaned_locations:
            cleaned_locations.append(location)
    
    return cleaned_locations

# Call the function and print the cleaned locations
cleaned_locations = clean_locations(locations)
print(cleaned_locations)
# Out:
# ['India', 'America', 'West', 'Puri', 'Orissa', 'Bay Of Bengal', 'United States', 'Americas', 'England', 'California', 'Temple Of Jagannath', 'of', 'World', 'Babylon', 'Egypt', 'Gorakhpur', 'United Provinces', 'Benares', 'Ichapur', 'Bengal', 'Himalayas', 'Lahore', 'Punjab', 'York:', 'Semudoss St', 'Madras', 'Calcutta', 'Bareilly', 'Amherst Street', 'Heaven', 'Naini Tal', 'Sheoli', 'Ganges', 'Riverbank', 'Gurpar Road', 'Chadni Chowk', 'Burdwan', 'Hardwar', 'M', 'Moghul Ser', 'Rishikesh', 'Serampore', 'Howrah', 'Khulna', 'Thebes', 'Kalighat Temple', 'Tibet', 'Asia', 'Europe', 'East', 'Fontainebleau', 'Bhowanipur', 'Cooch Behar', 'Upper Circular', 'Ram Mohan Roy Road', 'Nagendra Math', 'Mathematics', 'Ashram', 'Cambridge', 'Nalanda', 'Taxila', 'Botany', 'Pennsylvania', 'Street', 'Washington', 'D', 'City', 'Konnersreuth', 'Bavaria', 'Dakshineswar Temple', 'Temple Of Kali', 'Dakshineswar', 'Merciful Presence', 'Goldighi', 'Calcutta Bathing Ghats', 'Nantu', 'Rana Mahal', 'Rai Ghat Lane', 'K
# ...

# %%
import csv

# List of locations
pa Samadhi', 'Nirbikalpa Samadhi', 'Hiranyaloka-is', 'Sea Of Bliss', 'Ocean', 'Maganvadi', 'Gandhi', 'Wardha?', 'Wardha Idyl;', 'Danse', 'New', 'Pondicherry', '(ahmedabad:', 'Poona', 'Jamshedpur', 'Elysium', 'Ranchi;', 'Dehra Dun', 'Dacca', 'Nawabganj', 'Purulia;', 'Purulia', 'Biur', 'Giri Bala', 'Bankura', 'Doorway-giri Bala!', 'Nawabganj Ghat', 'Memphis', 'Grosvenor House', 'Whitefields Congregational Church', 'Windsor House', 'Southampton', 'Corners-palestine', 'Belgium', 'Nebraska', 'Chicago', 'Los', 'Encinitas', 'Land', 'Dreams', 'The Temple Of Silence', 'Carnegie Hall', 'Friendship Heights', 'Olive Hill', 'Los Angeles Planetarium', 'San Diego Bay', 'Philippines', 'Africa', 'San Francisco', 'Coast']

def clean_locations(locations):
    cleaned_locations = []
    for location in locations:
        # Remove leading and trailing whitespaces
        location = location.strip()

        # Replace special characters with appropriate characters
        location = re.sub(r'[^\x00-\x7F]+', '', location)

        # Capitalize the first letter of each word
        location = ' '.join(word.capitalize() for word in location.split())

        # Replace known abbreviations with full words
        replacements = {
            "Of": "of",
            "St": "Street",
            "Math": "Mathematics",
            "C": "City",
            "Rai Ghat": "Rai Ghat",
            "Mela": "Fair",
            "Ghat": "Riverbank",
            "Is": "Island",
            "Wardha Idyl": "Wardha",
            "Danse Macabre": "Danse",
            "Brindaban—See": "Brindaban",
            "Ahmedabad": "Ahmedabad",
            "Sudra": "Sudra",
            "Vaisya": "Vaisya",
            "Kshatriya": "Kshatriya",
            "Brahmin": "Brahmin"
        }
        location = replacements.get(location, location)

        # Remove duplicates
        if location not in cleaned_locations:
            cleaned_locations.append(location)

    return cleaned_locations

# Call the function and print the cleaned locations
cleaned_locations = clean_locations(locations)

# Write the locations to a CSV file
with open('cleaned_locations.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Location'])
    for location in cleaned_locations:
        writer.writerow([location])

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
#After many rounds of cleaning, this is the final list

import csv

# List of places and locations
places_and_locations = [
    'India', 'America', 'West', 'Puri', 'Orissa', 'Bay of Bengal', 'United States', 'Americas', 'England', 'California', 
    'Temple of Jagannath', 'World', 'Babylon', 'Egypt', 'Gorakhpur', 'United Provinces', 'Benares', 'Ichapur', 
    'Bengal', 'Himalayas', 'Lahore', 'Punjab', 'York', 'Semudoss St', 'Madras', 'Calcutta', 'Bareilly', 'Amherst Street', 
    'Heaven', 'Naini Tal', 'Sheoli', 'Ganges', 'Riverbank', 'Gurpar Road', 'Chadni Chowk', 'Burdwan', 'Hardwar', 
    'Moghul Ser', 'Rishikesh', 'Serampore', 'Howrah', 'Khulna', 'Thebes', 'Kalighat Temple', 'Tibet', 'Asia', 'Europe', 
    'East', 'Fontainebleau', 'Bhowanipur', 'Cooch Behar', 'Upper Circular', 'Ram Mohan Roy Road', 'Nagendra Math', 
    'Mathematics', 'Ashram', 'Cambridge', 'Nalanda', 'Taxila', 'Botany', 'Pennsylvania', 'Street', 'Washington', 
    'City', 'Konnersreuth', 'Bavaria', 'Dakshineswar Temple', 'Temple of Kali', 'Dakshineswar', 'Merciful Presence', 
    'Goldighi', 'Calcutta Bathing Ghats', 'Nantu', 'Rana Mahal', 'Rai Ghat Lane', 'Kasi', 'Lahiri Mahasaya', 'Brindaban', 
    'Agra', 'Taj Mahal', 'Amoyima', 'Drongiri Mountains', 'Ranikhet', 'Madanamohana Temple', 'Taj', 'Muttra', 'Jerusalem', 
    'Eden', 'Idyl', 'Maya', 'Mount Washington Estates', 'Los Angeles', 'Hollywood', 'Ranchi', 'Pacific', 'Shankara', 
    'Sylvan', 'Kashmir', 'Edinburgh', 'Ranbajpur', 'Tarakeswar', 'Lourdes', 'France', 'Rai Ghat Road', 'Cosmic Sea', 
    'Vales', 'Mirth', 'London', 'Serampore', 'New York', 'Milky Way', 'Pasadena', 'Panthi', 'Serampore Courthouse', 
    'Himavat', 'Simla', 'Layan Hills', 'West Somerville', 'Massachusetts', 'Rawalpindi', 'Srinagar', 'Jhelum River', 
    'Mount Washington', 'Gulmarg', 'Khilanmarg', 'Shalimar', 'Nishat Bagh', 'Kabul', 'Dal Lake', 'Lady of Kashmir', 
    'Alps', 'Loch Lomond', 'Scotland', 'Alaska', 'Pikes Peak', 'Denver', 'Xochimilco', 'Mexico', 'Yellowstone National Park', 
    'Grand Canyon', 'Colorado', 'Al Aska', 'Yellowstone Park', 'Wyoming', 'Paint', 'Yosemite', 'Orient', 'Niagara', 
    'Mammoth Caves', 'Kentucky', 'Carlsbad Caverns', 'New Mexico', 'Mogul', 'Hindustan', 'Girish Vidyaratna Lane', 
    'Upper Circular Road', 'San Diego', 'Ganges River', 'Delhi', 'Sri Yukteswar', 'Giri', 'Sagar', 'Bharati', 
    'Aranya', 'Tirtha', 'Vedanta', 'Atlantis', 'Burma', 'China Sea', 'Japan', 'Kobe', 'Shanghai', 'Cleveland', 
    'China', 'Sabikalpa', 'Samadhi', 'Dihika', 'Kasimbazar', 'Bihar', 'Kasimbazar Palace', 'Yogoda Math', 'Midnapore', 
    'Lakshmanpur', 'Badrinarayan', 'Boston', 'Bowbazar', 'Serpentine Lane', 'Santiniketan', 'Israel', 'New York City', 
    'Archangel', 'Slovetsky Monastery', 'Dvina River', 'Garudeswar Mohulla', 'Badrinath', 'Kedarnath', 'Amarnath', 
    'Pasupatinath', 'Barackpur', 'Sodom', 'Ghurni', 'Nadia', 'Krishnagar', 'Jalangi River', 'Ghurni Shiva Site', 
    'Gazipur', 'Mirjapur', 'Danapur', 'Dasasamedh Bathing Ghat', 'Dasasamedh Ghat', 'Drongiri Mountain', 'Gogash River', 
    'Alpa Samadhi', 'Moradabad', 'Halua', 'Allahabad', 'Almora', 'Nanda Devi', 'British India', 'Mahamandal', 
    'Bengalitola', 'Bishnupur', 'Deogarh', 'Kriya', 'Indus', 'Tropics', 'Occident', 'Kumbha Mela', 'Se', 'Kidderpore', 
    'Rai Ghat', 'Manikarnika Ghat', 'Iples', 'Buddh Gaya', 'Aryavarta', 'Lahiri', 'Statue of Liberty', 'Santa Rosa', 
    'Burbank', 'Lebanon', 'U S A', 'Shining Abode', 'Mt Washington', 'Mount', 'Cincinnati', 'Caxton Hall', 'English Channel', 
    'Eichstatt', 'Germany', 'Bavariasee', 'Holland', 'Swiss Alps', 'Italy', 'Assisi', 'Greece', 'Mediterranean', 'Palestine', 
    'Holy Land', 'Bethlehem', 'Gethsemane', 'Calvary', 'Mount of Olives', 'River Jordan', 'Sea of G', 'Alilee', 'Birth Manger', 
    'Cairo', 'Red Sea', 'Arabian', 'Athens', 'Bombay', 'Taj Mahal Hotel', 'Howrah Station', 'Ranchi Vidyalaya', 'Ejmalichak', 
    'Wardha', 'Chamundi Temple', 'Mysore', 'Town Hall', 'Bangalore', 'Chetty Town Hall', 'Krishnaraja Sagar Dam', 'Hyderabad', 
    'Godavari River', 'Nilgiris', 'Mountains', 'Ellora', 'Ajanta', 'Kailasa', 'Hyderabad City', 'Mecca Masjid Mosque', 
    'Enic Wonderland', 'Belur', 'Afghanistan', 'Baluchistan', 'Seleucus', 'Patna', 'Hades', 'Persia', 'Susa', 'South India', 
    'Sravanabelagola', 'Travancore', 'Madras Presidency', 'Conjeeveram', 'Golden City', 'Nerur', 'Pudukkottai', 'Kaveri River', 
    'Madura', 'Mysore City', 'Kolar', 'Bhadravati', 'Sringeri Math', 'Albert Hall', 'Santosh', 'Fair', 'Jumna', 'Katayani Peith Ashram', 
    'Lahir', 'Brindabansee', 'Keshabananda', 'Jumna River', 'Chitor', 'Nasik', 'Ujjain', 'Regent Hotel', 'Kumbha Mela', 
    'Hiranyaloka', 'Illumined Astral Planet', 'Sabikalpa Samadhi', 'Nirbikalpa Samadhi', 'Hiranyaloka-is', 'Sea of Bliss', 
    'Ocean', 'Maganvadi', 'Gandhi', 'Wardha', 'Danse', 'New', 'Pondicherry', 'Poona', 'Jamshedpur', 'Elysium', 'Ranchi', 
    'Dehra Dun', 'Dacca', 'Nawabganj', 'Purulia', 'Biur', 'Giri Bala', 'Bankura', 'Memphis', 'Grosvenor House', 
    'Whitefields Congregational Church', 'Windsor House', 'Southampton', 'Belgium', 'Nebraska', 'Chicago', 'Encinitas', 
    'Los Angeles Planetarium', 'San Diego Bay', 'Philippines', 'Africa', 'San Francisco', 'Coast'
]

# Saving to CSV
with open('places_and_locations.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Place or Location'])
    for place in places_and_locations:
        writer.writerow([place])

# %%
#FINDING LOCATIONS

import csv
import requests

# Replace this with the path to your input CSV file
input_csv_path = 'cleaned_locations.csv'
# Output CSV file path
output_csv_path = 'wikidata_locations_with_geo.csv'

def get_geolocation(place_name):
    # Wikidata endpoint for SPARQL queries
    url = 'https://query.wikidata.org/sparql'
    # SPARQL query to get geolocation for a place name
    query = f"""
    SELECT ?place ?placeLabel ?location WHERE {{
      # ?place ?label "{place_name}"@en.
      # ?place wdt:P625 ?location.
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
    }}
    LIMIT 1
    """
    headers = {'User-Agent': 'MyApp/1.0 (myemail@example.com)', 'Accept': 'application/json'}
    try:
        response = requests.get(url, headers=headers, params={'query': query, 'format': 'json'})
        response.raise_for_status()  # Raises HTTPError, if one occurred
        data = response.json()
        results = data['results']['bindings']
        if results:
            location = results[0]['location']['value']
            # Extracting latitude and longitude from the point string
            lon, lat = location.replace('Point(', '').replace(')', '').split(' ')
            return lat, lon
    except Exception as e:
        print(f"Error fetching geolocation for {place_name}: {e}")
    return None, None

# Read place names from CSV
places = []
with open(input_csv_path, mode='r', encoding='utf-8') as infile:
    reader = csv.reader(infile)
    next(reader)  # Skip header
    for row in reader:
        places.append(row[0])  # Assuming place name is in the first column

# Fetch geolocations and write to a new CSV
with open(output_csv_path, mode='w', encoding='utf-8', newline='') as outfile:
    writer = csv.writer(outfile)
    writer.writerow(['Place Name', 'Latitude', 'Longitude'])
    for place in places:
        lat, lon = get_geolocation(place)
        if lat and lon:
            writer.writerow([place, lat, lon])
            print(f"Geolocation for {place}: {lat}, {lon}")
        else:
            print(f"No geolocation found for {place}")

print("\nDone writing geolocations to CSV.")
# Out:
# Geolocation for India: 22.8, 83.0
# Geolocation for America: 44.81455, 7.3152
# Geolocation for Puri: 19.8, 85.816666666
# Geolocation for Orissa: 20.15, 85.5
# Geolocation for Bay of Bengal: 15.0, 88.0
# Geolocation for United States: 39.828175, -98.5795
# Geolocation for England: 53.0, -1.0
# Geolocation for California: 44.545, -76.2761111
# No geolocation found for Temple of Jagannath
# Geolocation for Babylon: 32.541780555, 44.431644444
# Geolocation for Egypt: 44.27004, -79.3046
# Geolocation for Gorakhpur: 29.443802, 75.670266
# Geolocation for United Provinces: 52.08, 4.3
# Geolocation for Benares: 25.318888888, 83.012777777
# Geolocation for Ichapur: 22.90235, 88.7461
# Geolocation for Bengal: 23.9888, 88.7311
# Geolocation for Himalayas: 29.0, 84.0
# Geolocation for Lahore: 31.549722222, 74.343611111
# Geolocation for Punjab: 31.33, 74.21
# No geolocation found for Semudoss St
# Geolocation for Madras: 13.0825, 80.275
# Geolocation for Calcutta: 22.5726723, 88.3638815
# ...

# %%
import folium
from folium.plugins import MarkerCluster, HeatMap
import branca.colormap as cm

# Define the locations
locations = {
   
   
    "Khilanmarg, India": (34.048591, 74.380997),
    "Dal Lake, India": (34.121621, 74.833352),
    "Shalimar and Nishat Bagh, India": (34.148120, 74.873440),
    "Athens, Greece": (37.983810, 23.727539),
    "Bethlehem, Palestine": (31.705791, 35.200657),
    "Gethsemane, Palestine": (31.778091, 35.242428),
    "Calvary, Palestine": (31.778091, 35.242428),
    "Mount of Olives, Palestine": (31.778091, 35.242428),
    "River Jordan, Palestine": (32.160435, 35.620022),
    "Sea of Galilee, Palestine": (32.795864, 35.528658),
    "Cairo, Egypt": (30.044420, 31.235712),
    "Pyramids, Egypt": (29.979234, 31.134202),
    "Los Angeles, Mount Washington, USA": (34.100306, -118.220951),
    "Xochimilco, Mexico": (19.262896, -99.103381),
    "Yellowstone National Park, USA": (44.4280, -110.5885),
    "Grand Canyon, USA": (36.106965, -112.112997),
    "Alaska, USA": (66.160507, -153.369141),
    "Yosemite, USA": (37.865101, -119.538329),
    "Niagara Falls, USA": (43.096214, -79.037739),
    "Geolocation for India": (22.8, 83.0),
    "Geolocation for America": (44.81455, -7.3152),
    "Geolocation for Puri": (19.8, 85.816666666),
    "Geolocation for Orissa": (20.15, 85.5),
    "Geolocation for Bay of Bengal": (15.0, 88.0),
    "Geolocation for England": (54.863727415447286, -2.3130699248207134),
    "Geolocation for California": (36.54579943330155, -119.01108129077247),
    "Geolocation for Babylon": (38.99933591749132, -121.24169254454695),
    "Geolocation for Egypt": (26.8206,30.8025),
    "Geolocation for Gorakhpur": (29.443802, 75.670266),
    "Geolocation for Benares": (25.318888888, 83.012777777),
    "Geolocation for Ichapur": (22.90235, 88.7461),
    "Geolocation for Bengal": (23.9888, 88.7311),
    "Geolocation for Himalayas": (29.0, 84.0),
    "Geolocation for Lahore": (31.549722222, 74.343611111),
    "Geolocation for Punjab": (31.33, 74.21),
    "Geolocation for Madras": (13.0825, 80.275),
    "Geolocation for Calcutta": (22.5726723, 88.3638815),
    "Geolocation for Bareilly": (28.364, 79.415),
    "Geolocation for Burdwan": (23.25, 87.85),
    "Geolocation for Hardwar": (29.9, 78.1),
    "Geolocation for Rishikesh": (30.1, 78.3),
    "Geolocation for Jagganath":(19.805170029887538, 85.81801370572938),
    "Geolocation for Sembudoss Street":(13.094014366650933, 80.28742417492371),
    "Geolocation for Naini Tal":(29.392618386253805, 79.45647463536963),
    "Geoloaction for Garpar Road":(22.58060998041634, 88.37574240320852),
    "Geoloaction for Ram Mohan Roy Road":(22.58184585673879, 88.37516252979891),
    "Geoloaction for Nagendra Math":(22.58179951690244, 88.37500287543783),
    "Geolocation for Dakshineshwar Temple":(22.654940865993353, 88.35814035800415),
    "Geolocation for Rai Ghat Lane":(22.75830844682918, 88.34262697072057),
    "Geolocation for Kalighat Temple":(22.520586990896206, 88.34209843434888),
    "Geolocation for Bhowanipore":(22.53360703053182, 88.34625318173028),
    "Geolocation of Dunagiri":(30.51636171030412, 79.86863685573464),
    "Geolocation of Madan Mohana Temple":(20.19900835747706, 85.83674237515808),
    "Geolocation of Ranbagpur":(22.90129823083978, 87.92588677563984),
    "Geolocation of Panthi":(21.451621148735594, 81.98776505704134),
    "Geolocation Layan Hills":(9.288821935643337, 99.05549064141378),
     "Geolocation for Dashashwamedh Ghat":(25.30644813612349, 83.0102535185636),
     "Geolocation for Gagas River":(29.70160561776471, 79.29405481898759),
     "Geolocation for Bodh Gaya":(24.69311352397149, 84.98933270890527),
     "Geolocation of Solovetsky Monastery ":(65.02614044691815, 35.71436907545735),
     "Geolocation of  Dvina River":(62.82718062833714, 43.23608707013654),
     "Geolocation of Kasim Bazar":(24.119673550234996, 88.27419493076717),
    "Geolocation for Serampore": (22.75, 88.34),
    "Geolocation for Yogada Math":(22.663475954930554, 88.35779070248141),
    "Geolocation for Badrinarayan":(26.628463707432008, 83.67245131199894),
    "Geolocation for Mysore":(12.297724618644898, 76.63963609620787),
    "Geolocation for Sringeri Math":(12.307309721772404, 76.69750614990798),
    "Geolocation for Katyani Mandir":(30.1094902228825, 78.30793157584789),
    "Geolocation for Pashupatinath":(27.710739912501584, 85.34881250504576),
    "Geolocation for Amarnath" :(34.21592241703862, 75.50412010680998),
    "Geolocation for Maganvadi":(21.36959204023121, 79.26503930839212),
    "Geolocation for Ghurni Shiva Temple":(23.424102372600025, 88.5102836041907),
    "Geolocation for Carlsbad Caverns National Park":(32.14688433260288, -104.54287239345078),
    "Geolocation for Girish Vidyaratna Ln":(22.57850924415883, 88.38536818704854),
    "Geolocation for  Krishna Raja Sagara Dam":(12.508475788866813, 76.58470827148884),
    "Geolocation for Ellora Caves":(20.026925484220325, 75.17708690200227),
    "Geolocation for Howrah": (22.58, 88.329444444),
    "Geolocation for Khulna": (22.816666666, 89.55),
    "Geolocation for Thebes": (38.320833333, 23.317777777),
    "Geolocation for Tibet": (29.65, 91.1),
    "Geolocation for Hyderabad":(17.36780933117999, 78.46110154066645),
    "Geolocation for Europe": (58.75421933, -2.99209974),
    "Geolocation for Fontainebleau": (48.408888888, 2.701666666),
    "Geolocation for Cooch Behar": (26.316666666, 89.433333333),
    "Geolocation for Cambridge": (40.286178, -100.1768),
    "Geolocation for Nalanda": (25.2, 85.52),
    "Geolocation for Taxila": (33.745833333, 72.7875),
    "Geolocation for Pennsylvania": (41.0, -77.5),
    "Geolocation for Washington": (58.627486454, -5.018131892),
    "Geolocation for Konnersreuth": (50.016666666, 12.233333333),
    "Geolocation for Bavaria": (49.078611111, 11.385555555),
    "Geolocation for Dakshineswar": (22.655431, 88.357862),
    "Geolocation for Kasi": (25.310775, 83.010613888),
    "Geolocation for Brindaban": (27.572777777, 77.693333333),
    "Geolocation for Agra": (27.0349, 78.7716),
    "Geolocation for Ranikhet": (29.643055555, 79.433333333),
    "Geolocation for Muttra": (27.4924134, 77.673673),
    "Geolocation for Jerusalem": (31.617402, -3.7128404),
    "Geolocation for Los Angeles": (34.51928, -118.60152),
    "Geolocation for Hollywood": (33.472777777, -86.783055555),
    "Geolocation for Kashmir": (34.5, 76.0),
    "Geolocation for Edinburgh": (55.95, -3.3725),
    "Geolocation for Tarakeswar": (22.89, 88.02),
    "Geolocation for Lourdes": (43.094166666, -0.046944444),
    "Geolocation for France": (47.289282, -2.190231),
    "Geolocation for Vales": (41.473333333, -7.346666666),
    "Geolocation for London": (56.325515488, -2.680750173),
    "Geolocation for New York": (40.1324134, -73.5666325),
    "Geolocation for Pasadena": (34.676111111, -118.173888888),
    "Geolocation for Simla": (31.103333333, 77.172222222),
    "Geolocation for West Somerville": (42.3959299, -71.122553),
    "Geolocation for Massachusetts": (42.3, -71.8),
    "Geolocation for Rawalpindi": (33.333333333, 73.25),
    "Geolocation for Srinagar": (34.091111111, 74.806111111),
    "Geolocation for Mount Washington": (44.270827777, -71.303483333),
    "Geolocation for Gulmarg": (34.05, 74.38),
    "Geolocation for Shalimar": (30.444444444, 86.581944444),
    "Geolocation for Kabul": (34.532777777, 69.165833333),
    "Geolocation for Alps": (46.578055555, 8.615),
    "Geolocation for Loch Lomond": (56.1482, -4.6515),
    "Geolocation for Scotland": (55.795663767, -6.070684835),
    "Geolocation for Pikes Peak": (38.840555555, -105.044166666),
    "Geolocation for Denver": (39.739166666, -104.984722222),
    "Geolocation for Xochimilco": (19.275, -99.138888888),
    "Geolocation for Mexico": (23.0, -102.0),
    "Geolocation for Grand Canyon": (36.0975, -112.095278),
    "Geolocation for Colorado": (41.138873, -105.96762),
    "Geolocation for Alaska": (57.512909026, -151.73459169),
    "Geolocation for Wyoming": (42.95383, -107.12288),
    "Geolocation for Yosemite": (37.7425, -119.5375),
    "Geolocation for Niagara": (42.8842, -78.9142),
    "Geolocation for Kentucky": (37.5, -85.0),
    "Geolocation for New Mexico": (34.0, -106.0),
    "Geolocation for San Diego": (32.715, -117.1625),
    "Geolocation for Delhi": (28.666666666, 77.216666666),
    "Geolocation for Atlantis": (51.6615, -5.2585),
    "Geolocation for Burma": (22.0, 96.0),
    "Geolocation for Japan": (35.196055555, 139.627833333),
    "Geolocation for Kobe": (34.690166666, 135.195444444),
    "Geolocation for Shanghai": (31.166666666, 121.466666666),
    "Geolocation for Cleveland": (41.5667, -81.383),
    "Geolocation for China": (56.044482, 12.695108),
    "Geolocation for Dihika": (23.64136, 86.901551),
    "Geolocation for Bihar": (25.37, 85.13),
    "Geolocation for Lakshmanpur": (23.06027, 86.30722),
    "Geolocation for Boston": (42.0434657, -71.9424209),
    "Geolocation for Bowbazar": (22.57, 88.359),
    "Geolocation for Santiniketan": (23.68, 87.68),
    "Geolocation for Israel": (31.222222222, 64.838888888),
    "Geolocation for New York City": (40.7, -74.0),
    "Geolocation for Badrinath": (30.742425, 79.496038888),
    "Geolocation for Kedarnath": (30.73333333, 79.06666667),
    "Geolocation for Sodom": (31.2, 35.5),
    "Geolocation for Ghurni": (23.25, 88.34),
    "Geolocation for Nadia": (23.4, 88.5),
    "Geolocation for Krishnagar": (25.22625, 88.72203),
    "Geolocation for Jalangi River": (23.4119, 88.3808),
    "Geolocation for Gazipur": (23.988888888, 90.375),
    "Geolocation for Mirjapur": (23.58517, 88.34179),
    "Geolocation for Danapur": (25.633333333, 85.05),
    "Geolocation for Moradabad": (28.843236111, 78.728741666),
    "Geolocation for Allahabad": (25.45, 81.85),
    "Geolocation for Almora": (29.62, 79.67),
    "Geolocation for Bishnupur": (23.073888888, 87.32),
    "Geolocation for Deogarh": (24.526, 78.238),
    "Geolocation for Indus": (23.9944, 67.4308),
    "Geolocation for Kidderpore": (22.53, 88.32),
    "Geolocation for Manikarnika Ghat": (25.31087056, 83.01408556),
    "Geolocation for Santa Rosa": (24.631111111, -106.012777777),
    "Geolocation for Burbank": (34.180277777, -118.328333333),
    "Geolocation for Lebanon": (33.833333, 35.766667),
    "Geolocation for Mt Washington": (49.75, -125.29),
    "Geolocation for Cincinnati": (39.1, -84.5125),
    "Geolocation for English Channel": (50.0, -2.0),
    "Geolocation for Germany": (45.570211, -66.626889),
    "Geolocation for Holland": (44.41646, -80.78319),
    "Geolocation for Swiss Alps": (46.5, 8.5),
    "Geolocation for Italy": (42.253333333, 13.946111111),
    "Geolocation for Assisi": (43.07, 12.6175),
    "Geolocation for Greece": (38.5, 23.0),
    "Geolocation for Mediterranean": (35.696944444, -0.633055555),
    "Geolocation for Palestine": (31.625321, 35.145264),
    "Geolocation for Bethlehem": (31.704444444, 35.206111111),
    "Geolocation for Gethsemane": (31.779419, 35.239425),
    "Geolocation for Calvary": (50.742227, 14.310984),
    "Geolocation for Mount of Olives": (31.777946, 35.245686),
    "Geolocation for Cairo": (30.044444444, 31.235833333),
    "Geolocation for Athens": (37.984166666, 23.728055555),
    "Geolocation for Bombay": (19.075833333, 72.8775),
    "Geolocation for Wardha": (20.75, 78.616666666),
    "Geolocation for Mysore": (12.308611111, 76.653055555),
    "Geolocation for Bangalore": (12.9791198, 77.5912997),
    "Geolocation for Hyderabad": (17.361666666, 78.474722222),
    "Geolocation for Ajanta": (20.5333, 75.75),
    "Geolocation for Afghanistan": (33.0, 66.0),
    "Geolocation for Baluchistan": (30.12, 67.01),
    "Geolocation for Patna": (25.61, 85.141388888),
    "Geolocation for Persia": (32.0, 53.0),
    "Geolocation for Susa": (45.133333, 7.05),
    "Geolocation for Travancore": (8.433333333, 76.916666666),
    "Geolocation for Nerur": (15.98333333, 73.65),
    "Geolocation for Pudukkottai": (10.383333333, 78.816666666),
    "Geolocation for Kolar": (13.133333333, 78.133333333),
    "Geolocation for Bhadravati": (20.109722222, 79.12),
    "Geolocation for Chitor": (25.52619, 88.17036),
    "Geolocation for Nasik": (20.0, 73.783333333),
    "Geolocation for Ujjain": (23.182777777, 75.777222222),
    "Geolocation for Pondicherry": (11.93, 79.83),
    "Geolocation for Poona": (18.519574, 73.855287),
    "Geolocation for Jamshedpur": (22.8, 86.183333333),
    "Geolocation for Ranchi": (23.355555555, 85.334722222),
    "Geolocation for Dehra Dun": (30.318, 78.029),
    "Geolocation for Dacca": (23.728888888, 90.394444444),
    "Geolocation for Nawabganj": (26.94, 81.19),
    "Geolocation for Purulia": (47.807138888, 24.822777777),
    "Geolocation for Biur": (23.19047, 87.59354),
    "Geolocation for Bankura": (23.25, 87.066666666),
    "Geolocation for Memphis": (29.85412, 31.25934),
    "Geolocation for Southampton": (50.950277777, -1.356666666),
    "Geolocation for Belgium": (50.97093, 5.65382),
    "Geolocation for Nebraska": (41.5, -100.0),
    "Geolocation for Chicago": (57.411566067, -1.826874223),
    "Geolocation for Encinitas": (33.044444444, -117.271666666),
    "Geolocation for San Diego Bay": (32.64805, -117.19116),
    "Geolocation for Philippines": (12.0, 123.0),
    "Geolocation for Africa": (55.735508586, -5.605304672),
    "Geolocation for San Francisco": (37.796944444, -122.394722222)
}

# Create a map with marker clusters
cluster_map = folium.Map(location=[20, 78], zoom_start=2)
marker_cluster = MarkerCluster().add_to(cluster_map)

for city, coords in locations.items():
    folium.Marker(
        location=coords,
        popup=f"{city}",
        icon=folium.Icon(icon='cloud')
    ).add_to(marker_cluster)

# Generate heatmap data
heatmap_data = [[coord[0], coord[1], 1] for coord in locations.values()]

# Add heatmap layer
HeatMap(heatmap_data).add_to(cluster_map)

# Define a color map
color_scale = cm.LinearColormap(['blue', 'green', 'yellow', 'orange', 'red'],
                                vmin=0, vmax=100)

# Add color index legend to the map
color_scale.add_to(cluster_map)

# Save the map to an HTML file
cluster_map.save('travel_heatmap_book1.html')
